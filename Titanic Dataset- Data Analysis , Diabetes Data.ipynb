# %%
import pandas as pd

# %%
titanic_data=pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/Titanic_Data.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_data.columns[0:3]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass'], dtype='object')

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.shape[0]
# Out:
# 891

# %% [markdown]
# <h3>Data Manupulation </h3>

# %%
##Loc takes values in the way it is defined in Df
#all rows & columns
titanic_data.loc[:,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
##Filter the row using row values

titanic_data.loc[100:500,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 100          101         0       3
# 101          102         0       3
# 102          103         0       1
# 103          104         0       3
# 104          105         0       3
# ..           ...       ...     ...
# 496          497         1       1
# 497          498         0       3
# 498          499         0       1
# 499          500         0       3
# 500          501         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 100                          Petranec, Miss. Matilda  female  28.0      0
# 101                 Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 102                        White, Mr. Richard Frasar    male  21.0      0
# 103                       Johansson, Mr. Gustaf Joel    male  33.0      0
# 104                   Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# ..                                               ...     ...   ...    ...
# ...

# %%
#filter the column using column indexes
titanic_data.loc[:,['Survived','Pclass','Age']]
# Out:
#      Survived  Pclass   Age
# 0           0       3  22.0
# 1           1       1  38.0
# 2           1       3  26.0
# 3           1       1  35.0
# 4           0       3  35.0
# ..        ...     ...   ...
# 886         0       2  27.0
# 887         1       1  19.0
# 888         0       3   NaN
# 889         1       1  26.0
# 890         0       3  32.0
#
# [891 rows x 3 columns]

# %%
#slicing of rows using index values
titanic_data.iloc[2:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 2                         Heikkinen, Miss. Laina  female  26.0      0      0
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                       Allen, Mr. William Henry    male  35.0      0      0
# 5                               Moran, Mr. James    male   NaN      0      0
# 6                        McCarthy, Mr. Timothy J    male  54.0      0      0
# ..                                           ...     ...   ...    ...    ...
# ...

# %%
#slicing of rows and columns
titanic_data.iloc[100:601,5:len(titanic_data.columns)]
# Out:
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 100  28.0      0      0    349245   7.8958   NaN        S
# 101   NaN      0      0    349215   7.8958   NaN        S
# 102  21.0      0      1     35281  77.2875   D26        S
# 103  33.0      0      0      7540   8.6542   NaN        S
# 104  37.0      2      0   3101276   7.9250   NaN        S
# ..    ...    ...    ...       ...      ...   ...      ...
# 596   NaN      0      0    248727  33.0000   NaN        S
# 597  49.0      0      0      LINE   0.0000   NaN        S
# 598   NaN      0      0      2664   7.2250   NaN        C
# 599  49.0      1      0  PC 17485  56.9292   A20        C
# 600  24.0      2      1    243847  27.0000   NaN        S
#
# [501 rows x 7 columns]

# %%
#gives the second third last coulmn
titanic_data.iloc[:,-3]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#Slicing and display last 3 coulmns
titanic_data.iloc[:,-3:]
# Out:
#         Fare Cabin Embarked
# 0     7.2500   NaN        S
# 1    71.2833   C85        C
# 2     7.9250   NaN        S
# 3    53.1000  C123        S
# 4     8.0500   NaN        S
# ..       ...   ...      ...
# 886  13.0000   NaN        S
# 887  30.0000   B42        S
# 888  23.4500   NaN        S
# 889  30.0000  C148        C
# 890   7.7500   NaN        Q
#
# [891 rows x 3 columns]

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# <h3>Handling Missing values</h3>

# %%
#gives true and false
titanic_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#gives counts of missing values
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data.drop(['Cabin'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.drop(['Cabin'],axis=1,inplace=True)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data['Age'].median()
# Out:
# 28.0

# %%
titanic_data['Age'].mean()
# Out:
# 29.69911764705882

# %%
import numpy as np

# %%
titanic_data['Age'].replace(np.nan,titanic_data['Age'].median(),inplace=True)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
titanic_data.dropna(inplace=True)

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic_data.boxplot(figsize=(20,10))

# %%
titanic_data['Age'].plot(figsize=(20,8),color='darkorange')

# %%
diabetes_df=pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/Diabetes_Preprocessing.csv')

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0            4.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627    5        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %%
diabetes_df.isnull().sum().sort_values(ascending=False)
# Out:
# Insulin                     374
# SkinThickness               227
# BloodPressure                35
# BMI                          11
# Glucose                       5
# Outcome                       0
# Age                           0
# DiabetesPedigreeFunction      0
# Pregnancies                   0
# dtype: int64

# %% [markdown]
# <h3>How to handle missing values</h3>

# %%
from sklearn.impute import SimpleImputer
impute=SimpleImputer(strategy='median')
diabetes_data=impute.fit_transform(diabetes_df)
#finally it will convert it into 2-d array

# %%
diabetes_data
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,   5.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,   3.   ,   0.   ],
#        [  1.   , 126.   ,   6.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,   7.   , ...,   0.315,  23.   ,   0.   ]])

# %%
#to typecast back in dataframe
pd.DataFrame(diabetes_data,columns=diabetes_df.columns)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0     71.0  33.6
# 1            1.0     85.0           66.0           29.0     71.0  26.6
# 2            8.0    183.0           64.0           27.0     71.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0            4.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0     11.0           76.0           48.0     18.0  32.9
# 764          2.0    122.0            7.0           27.0     71.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0            6.0           27.0     71.0   3.1
# 767          1.0     93.0            7.0           31.0     71.0   3.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627   5.0      1.0
# ...
